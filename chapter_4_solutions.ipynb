# %% [markdown]
# ## 4-1. Pizzas

# %%
pizzas = ["pepperoni", "margherita", "chicken fajita"]

for pizza in pizzas:
    print(pizza)

for pizza in pizzas:
    print(f"I like {pizza} pizza.")

print("I really love pizza!")

# %% [markdown]
# ## 4-2. Animals

# %%
animals = ["dog", "cat", "rabbit"]

for animal in animals:
    print(animal)

for animal in animals:
    print(f"A {animal} would make a great pet.")

print("Any of these animals would make a great pet.")

# %% [markdown]
# ## 4-3. Counting to Twenty

# %%
for number in range(1, 21):
    print(number)

# %% [markdown]
# ## 4-4. One Million

# %%
numbers = list(range(1, 1_000_001))

for number in numbers:
    print(number)

# %% [markdown]
# ## 4-5. Summing a Million

# %%
numbers = list(range(1, 1_000_001))

print(min(numbers))
print(max(numbers))
print(sum(numbers))

# %% [markdown]
# ## 4-6. Odd Numbers

# %%
odd_numbers = list(range(1, 21, 2))

for number in odd_numbers:
    print(number)

# %% [markdown]
# ## 4-7. Threes

# %%
multiples_of_three = list(range(3, 31, 3))

for number in multiples_of_three:
    print(number)

# %% [markdown]
# ## 4-8. Cubes

# %%
cubes = []

for number in range(1, 11):
    cubes.append(number ** 3)

for cube in cubes:
    print(cube)

# %% [markdown]
# ## 4-9. Cube Comprehension

# %%
cubes = [number ** 3 for number in range(1, 11)]

for cube in cubes:
    print(cube)

# %% [markdown]
# ## 4-10. Slices

# %%
numbers = list(range(1, 11))

print("The first three items in the list are:")
print(numbers[:3])

print("Three items from the middle of the list are:")
print(numbers[3:6])

print("The last three items in the list are:")
print(numbers[-3:])

# %% [markdown]
# ## 4-11. My Pizzas, Your Pizzas

# %%
pizzas = ["pepperoni", "margherita", "chicken fajita"]
friend_pizzas = pizzas[:]

pizzas.append("BBQ chicken")
friend_pizzas.append("Hawaiian")

print("My favorite pizzas are:")
for pizza in pizzas:
    print(pizza)

print("\nMy friend's favorite pizzas are:")
for pizza in friend_pizzas:
    print(pizza)

# %% [markdown]
# ## 4-12. More Loops

# %%
my_foods = ["pizza", "falafel", "carrot cake"]
friend_foods = ["pizza", "ice cream", "carrot cake"]

print("My favorite foods are:")
for food in my_foods:
    print(food)

print("\nMy friend's favorite foods are:")
for food in friend_foods:
    print(food)

# %% [markdown]
# ## 4-13. Buffet

# %%
foods = ("pizza", "burger", "pasta", "salad", "rice")

for food in foods:
    print(food)

# Tuples cannot be modified after they are created.
# foods[0] = "sushi"

foods = ("sushi", "burger", "noodles", "salad", "rice")

print("\nRevised menu:")
for food in foods:
    print(food)

# %% [markdown]
# ## 4-14. PEP 8

# %%
# Read the PEP 8 style guide:
# https://peps.python.org/pep-0008/

# %% [markdown]
# ## 4-15. Code Review

# %%
# PEP 8-compliant version of a Chapter 4 program.

pizzas = ["pepperoni", "margherita", "chicken fajita"]

for pizza in pizzas:
    print(f"I like {pizza} pizza.")

print("I really love pizza!")
