# %% [markdown]
# ## 2-1. Simple Message
#
# Store a message in a variable, and then print that message.

# %%
message = "I am learning Python."
print(message)

# %% [markdown]
# ## 2-2. Simple Messages
#
# Store a message in a variable and print it. Then change the value of the variable to a new message and print the new message.

# %%
message = "I am learning Python."
print(message)

message = "Python is becoming easier."
print(message)

# %% [markdown]
# ## 2-3. Personal Message
#
# Store a person's name in a variable and print a message to that person.

# %%
name = "Eric"
print(f"Hello {name}, would you like to learn some Python today?")

# %% [markdown]
# ## 2-4. Name Cases
#
# Store a person's name and print it in lowercase, uppercase, and titlecase.

# %%
name = "Eric"

print(name.lower())
print(name.upper())
print(name.title())

# %% [markdown]
# ## 2-5. Famous Quote
#
# Find a quote from a famous person you admire and print the quote and its author.

# %%
print('Albert Einstein once said, "A person who never made a mistake never tried anything new."')

# %% [markdown]
# ## 2-6. Famous Quote 2
#
# Store the famous person's name in a variable called famous_person, compose the message in a variable called message, and print it.

# %%
famous_person = "Albert Einstein"

message = f'{famous_person} once said, "A person who never made a mistake never tried anything new."'

print(message)

# %% [markdown]
# ## 2-7. Stripping Names
#
# Store a person's name with whitespace at the beginning and end. Use both \t and \n, then demonstrate lstrip(), rstrip(), and strip().

# %%
name = "\tEric\n"

print(name)
print(name.lstrip())
print(name.rstrip())
print(name.strip())

# %% [markdown]
# ## 2-8. Number Eight
#
# Write addition, subtraction, multiplication, and division operations that each result in 8.

# %%
print(5 + 3)
print(10 - 2)
print(4 * 2)
print(16 // 2)

# %% [markdown]
# ## 2-9. Favorite Number
#
# Store your favorite number in a variable and create a message that reveals it.

# %%
favorite_number = 7

message = f"My favorite number is {favorite_number}."

print(message)

# %% [markdown]
# ## 2-10. Adding Comments
#
# Choose two programs and add at least one comment to each. The examples below demonstrate this exercise.

# %%
# Store a person's name and display it in different cases.

name = "Eric"

print(name.lower())
print(name.upper())
print(name.title())

# %% [markdown]
# ## 2-11. Zen of Python
#
# Enter import this into a Python terminal session and skim through the additional principles.

# %%
import this
